# %% [markdown]
# Resultados do Exercício 1

# %%
import requests

response = requests.post('http://127.0.0.1:8000/chat', 
                        json={"message": "credo vc nunca acerta"})
print(response.text)
# Out:
# {"response":"Que interessante! Pode me contar mais?"}

# %% [markdown]
# Resultados do Exercício 2

# %%
import requests

response = requests.post('http://127.0.0.1:8000/translate', 
                        json={"text": "In a world where technology evolves at an unprecedented pace, the importance of adapting to change cannot be overstated. From artificial intelligence to renewable energy solutions, innovations are reshaping industries and redefining possibilities. As humanity continues to navigate challenges such as climate change, social inequality, and economic instability, collaboration and forward-thinking strategies become essential. Education plays a critical role in empowering individuals to contribute to these solutions, fostering creativity and resilience. By leveraging advancements in communication, we are more connected than ever before, bridging gaps and promoting global understanding. Yet, with this connectivity comes the responsibility to ensure ethical practices, data security, and respect for privacy. Balancing progress with sustainability requires a collective effort, embracing diverse perspectives and inclusive decision-making. As we look toward the future, the potential for growth, discovery, and harmony remains boundless, driven by the enduring human spirit and the pursuit of excellence. The journey of human innovation has always been fueled by curiosity and the desire to overcome limitations. From the invention of the wheel to the creation of the internet, each breakthrough has paved the way for new opportunities and challenges. Today, the rise of artificial intelligence, biotechnology, and space exploration marks a new era of possibilities. However, with these advancements come ethical dilemmas and the need for responsible governance. How do we ensure that technology serves humanity without causing harm? The answer lies in collaboration, transparency, and the establishment of global frameworks that prioritize equity and sustainability. Education, now more than ever, must focus on critical thinking, adaptability, and ethical awareness to prepare future generations for an uncertain yet promising future. By embracing diversity and innovation, we can work toward a world that thrives on inclusivity, resilience, and shared progress, leaving a legacy of hope and prosperity for all."})
print(response.text)
# Out:
# {"original":"In a world where technology evolves at an unprecedented pace, the importance of adapting to change cannot be overstated. From artificial intelligence to renewable energy solutions, innovations are reshaping industries and redefining possibilities. As humanity continues to navigate challenges such as climate change, social inequality, and economic instability, collaboration and forward-thinking strategies become essential. Education plays a critical role in empowering individuals to contribute to these solutions, fostering creativity and resilience. By leveraging advancements in communication, we are more connected than ever before, bridging gaps and promoting global understanding. Yet, with this connectivity comes the responsibility to ensure ethical practices, data security, and respect for privacy. Balancing progress with sustainability requires a collective effort, embracing diverse perspectives and inclusive decision-making. As we look toward the future, the potentia
# ...

# %% [markdown]
# Resultados do Exercício 3

# %%
import requests

response = requests.post('http://127.0.0.1:8000/translate', 
                        json={"text": "In a world where technology evolves at an unprecedented pace, the importance of adapting to change cannot be overstated. From artificial intelligence to renewable energy solutions, innovations are reshaping industries and redefining possibilities. As humanity continues to navigate challenges such as climate change, social inequality, and economic instability, collaboration and forward-thinking strategies become essential. Education plays a critical role in empowering individuals to contribute to these solutions, fostering creativity and resilience. By leveraging advancements in communication, we are more connected than ever before, bridging gaps and promoting global understanding. Yet, with this connectivity comes the responsibility to ensure ethical practices, data security, and respect for privacy. Balancing progress with sustainability requires a collective effort, embracing diverse perspectives and inclusive decision-making. As we look toward the future, the potential for growth, discovery, and harmony remains boundless, driven by the enduring human spirit and the pursuit of excellence. The journey of human innovation has always been fueled by curiosity and the desire to overcome limitations. From the invention of the wheel to the creation of the internet, each breakthrough has paved the way for new opportunities and challenges. Today, the rise of artificial intelligence, biotechnology, and space exploration marks a new era of possibilities. However, with these advancements come ethical dilemmas and the need for responsible governance. How do we ensure that technology serves humanity without causing harm? The answer lies in collaboration, transparency, and the establishment of global frameworks that prioritize equity and sustainability. Education, now more than ever, must focus on critical thinking, adaptability, and ethical awareness to prepare future generations for an uncertain yet promising future. By embracing diversity and innovation, we can work toward a world that thrives on inclusivity, resilience, and shared progress, leaving a legacy of hope and prosperity for all."})
print(response.text)
# Out:
# {"original":"In a world where technology evolves at an unprecedented pace, the importance of adapting to change cannot be overstated. From artificial intelligence to renewable energy solutions, innovations are reshaping industries and redefining possibilities. As humanity continues to navigate challenges such as climate change, social inequality, and economic instability, collaboration and forward-thinking strategies become essential. Education plays a critical role in empowering individuals to contribute to these solutions, fostering creativity and resilience. By leveraging advancements in communication, we are more connected than ever before, bridging gaps and promoting global understanding. Yet, with this connectivity comes the responsibility to ensure ethical practices, data security, and respect for privacy. Balancing progress with sustainability requires a collective effort, embracing diverse perspectives and inclusive decision-making. As we look toward the future, the potentia
# ...
